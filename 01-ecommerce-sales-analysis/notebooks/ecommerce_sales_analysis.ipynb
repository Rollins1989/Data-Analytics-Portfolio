# %% [markdown]
# # E-commerce Sales Analysis
#
# Reproducible Pandas analysis of the supplied synthetic transaction dataset.
#
# The notebook uses the reusable analysis module in `src/`.

# %%
from pathlib import Path
import sys

PROJECT_DIR = Path.cwd().parent
sys.path.insert(0, str(PROJECT_DIR / 'src'))

from ecommerce_analysis import load_data, build_analysis

# %%
df = load_data()
results = build_analysis(df)
results['summary']

# %%
results['by_category']

# %%
results['by_region']

# %%
results['by_channel']

# %%
results['monthly']

# %% [markdown]
# ## Interpretation
#
# Use the outputs to discuss revenue concentration, customer behavior, channel performance, and monthly trends. The dataset is synthetic, so findings are illustrative.
